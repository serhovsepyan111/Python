# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./data/sampleSubmission.csv")

# %%
data.head()
# Out:
#    PhraseId  Sentiment
# 0    156061          2
# 1    156062          2
# 2    156063          2
# 3    156064          2
# 4    156065          2

# %%
data.dtypes
# Out:
# PhraseId     int64
# Sentiment    int64
# dtype: object

# %%
data.shape
# Out:
# (66292, 2)

# %%
data[['PhraseId']].head()
# Out:
#    PhraseId
# 0    156061
# 1    156062
# 2    156063
# 3    156064
# 4    156065

# %%
l = [1, 2, "apple"]

# %%
initial_list = list(data['PhraseId'])
initial_list
# Out:
# [156061,
#  156062,
#  156063,
#  156064,
#  156065,
#  156066,
#  156067,
#  156068,
#  156069,
#  156070,
#  156071,
#  156072,
#  156073,
#  156074,
#  156075,
#  156076,
#  156077,
#  156078,
#  156079,
#  156080,
#  156081,
#  156082,
#  156083,
#  156084,
#  156085,
#  156086,
#  156087,
#  156088,
#  156089,
#  156090,
#  156091,
#  156092,
#  156093,
#  156094,
#  156095,
#  156096,
#  156097,
#  156098,
#  156099,
#  156100,
#  156101,
#  156102,
#  156103,
#  156104,
#  156105,
#  156106,
#  156107,
#  156108,
#  156109,
#  156110,
#  156111,
#  156112,
#  156113,
#  156114,
#  156115,
#  156116,
#  156117,
#  156118,
#  156119,
#  156120,
#  156121,
#  156122,
#  156123,
#  156124,
#  156125,
#  156126,
#  156127,
#  156128,
#  156129,
#  156130,
#  156131,
#  156132,
#  156133,
#  156134,
#  156135,
#  156136,
#  156137,
#  156138,
#  156139,
#  156140,
#  156141,
#  156142,
#  156143,
#  156144,
#  156145,
#  156146,
#  156147,
#  156148,
#  156149,
#  156150,
# ...

# %%
anun = []
anun2 = []

for i in kkk:
    if i < 156091:
        anun.append(i)
    else:
        anun2.append(i)

# %%
def y(x):
    
    anun = []
    anun2 = []

    for i in x:
        if i < 156091:
            anun.append(i)
        else:
            anun2.append(i)
            
    return(anun, anun2)

# %%
y(initial_list)
# Out:
# ([156061,
#   156062,
#   156063,
#   156064,
#   156065,
#   156066,
#   156067,
#   156068,
#   156069,
#   156070,
#   156071,
#   156072,
#   156073,
#   156074,
#   156075,
#   156076,
#   156077,
#   156078,
#   156079,
#   156080,
#   156081,
#   156082,
#   156083,
#   156084,
#   156085,
#   156086,
#   156087,
#   156088,
#   156089,
#   156090],
#  [156091,
#   156092,
#   156093,
#   156094,
#   156095,
#   156096,
#   156097,
#   156098,
#   156099,
#   156100,
#   156101,
#   156102,
#   156103,
#   156104,
#   156105,
#   156106,
#   156107,
#   156108,
#   156109,
#   156110,
#   156111,
#   156112,
#   156113,
#   156114,
#   156115,
#   156116,
#   156117,
#   156118,
#   156119,
#   156120,
#   156121,
#   156122,
#   156123,
#   156124,
#   156125,
#   156126,
#   156127,
#   156128,
#   156129,
#   156130,
#   156131,
#   156132,
#   156133,
#   156134,
#   156135,
#   156136,
#   156137,
#   156138,
#   156139,
#   156140,
#   156141,
#   156142,
#   156143,
# ...

# %%
def y_(tr):
    a=[]
    for i in tr['Sentiment']:
        if i<156066:
            a.append(i)
    return(a)

# %%
y_( data)
# Out:
# [2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
# ...

# %%
#data.head()

# %%
#data['PhraseId']
